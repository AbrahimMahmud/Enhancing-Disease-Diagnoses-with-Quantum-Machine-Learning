# %% [markdown]
# The following illustration shows a generic base neural network model, Mp (Machine Learning model/ML-Model) trained on ImageNet dataset (Da). The base model is then used as the base for Transfer Learning, on Image Classification task (based on resnet18). The last layer of this pre-trained model (fully-connected/fc layer, A2) is then modified (to be A2') by a quantum means through a quantum machine learning framework: Pennylane.ai with a new dataset (Db), generating a new model (Mrt).
#
# The Quantum ML framework (which is open-source) provides convenient access to multiple quantum simulator and real quantum computer backend, including Pennylane's Lightning Qubit Device through an open-source Qiskit API (Application Programming Interface) accessible by Python programming language.

# %% [markdown]
# # 1. Preparation

# %% [markdown]
# ## Load required Python libraries

# %%
print("Installing libraries, this might take a while")

# !pip3 install -q torch
# !pip3 install -q pennylane
# !pip3 install -q matplotlib
# !pip3 install -q torchvision
# !pip3 install -q prettytable
# !pip3 install -q pennylane-qiskit

print("Building Simulator, this might take a while")

# !pip3 install pybind11 
# !pip3 install pennylane-lightning --no-binary :all: 
        
# System
import time
import os, platform, sys
import copy
from datetime import datetime

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms

# Pennylane
import pennylane as qml
from pennylane import numpy as np
from pennylane_qiskit import AerDevice

# Plotting
import matplotlib.pyplot as plt
# Out:
# Installing libraries, this might take a while
# Building Simulator, this might take a while
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.7/dist-packages (2.10.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pennylane-lightning in /usr/local/lib/python3.7/dist-packages (0.25.1)
# Requirement already satisfied: pennylane>=0.19 in /usr/local/lib/python3.7/dist-packages (from pennylane-lightning) (0.25.1)
# Requirement already satisfied: ninja in /usr/local/lib/python3.7/dist-packages (from pennylane-lightning) (1.10.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pennylane-lightning) (1.21.6)
# Requirement already satisfied: retworkx in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (0.11.0)
# Requirement already satisfied: semantic-version>=2.7 in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (2.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (1.7.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (4.2.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (2.6.3)
# Requirement already satisfied: autoray>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (0.3.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (0.10.2)
# Requirement already satisfied: autograd in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (1.4)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from pennylane>=0.19->pennylane-lightning) (1.4.4)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd->pennylane>=0.19->pennylane-lightning) (0.16.0)

# %%
print("[Python version]:", sys.version)
print("[Deep Learning framework, Pytorch (Facebook) version]:", torch.__version__)
print("[Quantum Machine Learning framework (Pennylane) version]:", qml.__version__)
# Out:
# [Python version]: 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]
# [Deep Learning framework, Pytorch (Facebook) version]: 1.12.1+cu113
# [Quantum Machine Learning framework (Pennylane) version]: 0.25.1

# %% [markdown]
# ## Set Parameters

# %%
! unzip /content/large_tb_dataset.zip

dataset_dir = "/content/TB_Chest_Radiography_Database"

num_epochs = 8                      # Number of training epochs (1 for testing, 8 for final)
n_qubits = 4                        # Number of qubits 
step = 0.0004                       # Learning rate
batch_size = 8                      # Number of samples for each training step
q_depth = 6                         # Depth of the quantum circuit (number of variational layers)
gamma_lr_scheduler = 0.1            # Learning rate reduction applied every 10 epochs.
q_delta = 0.01                      # Initial spread of random quantum weights
rng_seed = 3                        # Seed for random number generator
start_time = time.time()            # Start of the computation timer

model_fileext = ".pth"
log_fileext = ".log"
# Out:
# Archive:  /content/large_tb_dataset.zip
#    creating: TB_Chest_Radiography_Database/
#   inflating: TB_Chest_Radiography_Database/.DS_Store
#    creating: TB_Chest_Radiography_Database/val/
#   inflating: TB_Chest_Radiography_Database/val/.DS_Store
#    creating: TB_Chest_Radiography_Database/val/Normal/
#   inflating: TB_Chest_Radiography_Database/val/Normal/Normal-
png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-417.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-403.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-365.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-359.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-205.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-211.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-239.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-9.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-215.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-201.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-229.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-361.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-407.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-413.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-375.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-349.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-17.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-163.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-177.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-188.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-189.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-176.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-162.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-16.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-348.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-412.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-374.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-360.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-406.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-228.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-200.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-214.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-8.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-202.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-216.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-376.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-410.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-404.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-362.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-438.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-389.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-174.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-14.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-160.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-148.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-28.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-29.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-149.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-161.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-15.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-175.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-388.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-439.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-405.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-363.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-377.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-411.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-217.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-203.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-258.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-264.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-270.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-338.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-310.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-304.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-112.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-66.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-106.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-72.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-99.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-98.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-73.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-107.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-67.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-113.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-305.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-311.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-339.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-271.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-265.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-259.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-273.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-267.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-298.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-449.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-307.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-313.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-139.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-59.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-105.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-71.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-111.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-65.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-64.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-110.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-70.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-104.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-58.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-138.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-312.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-306.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-448.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-299.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-266.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-272.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-276.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-262.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-289.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-302.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-316.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-74.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-100.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-60.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-114.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-48.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-128.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-129.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-49.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-115.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-61.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-101.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-75.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-317.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-303.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-288.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-263.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-277.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-261.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-275.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-249.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-315.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-301.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-329.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-63.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-117.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-77.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-103.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-88.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-89.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-102.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-76.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-116.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-62.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-328.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-300.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-314.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-248.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-274.png
#   inflating: TB_Chest_Radiography_Database/train/Tuberculosis/Tuberculosis-260.png

# %% [markdown]
# ## Define Backend: Quantum Simulator

# %%
backend_name = "simPennylane"
print("=> Using Lightning Pennylane Quantum Computer Simulator (local)")
dev = qml.device("lightning.qubit", wires=n_qubits)
# Out:
# => Using Lightning Pennylane Quantum Computer Simulator (local)

# %%
now = datetime.now()
now_str = now.strftime("%d%m%Y%H%M%S")

# model & log file name to generate
# swgCQ_resnet18_ + selected backend name + max epochs + current date & time + extension
#   - pytorch model file extension '.pth'
#   - log file for the generated model file extension '.log'
base_filename = "abrahimmahmud_"
interim_model_name = base_filename + backend_name 
hybrid_model_name = base_filename + backend_name + "(" + str(num_epochs) + ")-" + now_str + model_fileext
log_filename = base_filename + backend_name + "(" + str(num_epochs) + ")-" + now_str + log_fileext

train_val_filename = base_filename + backend_name + "_train_val-results" + now_str

# %%
# USE NVidia CUDA (GPU) if available
# ----------------------------------
is_cuda_available = torch.cuda.is_available()
device = torch.device("cuda:0" if is_cuda_available else "cpu")
if is_cuda_available:
    print ("cuda is available, using:", device)
else:
    print ("cuda is not available, using:", device)
# Out:
# cuda is available, using: cuda:0

# %% [markdown]
# ## Prepare new dataset to retrain last layer (fc-layer) of pre-trained resnet-18

# %%
# initialize data loaders
data_transforms = {
    "train": transforms.Compose(
        [
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            # Normalize input channels using mean values and standard deviations of ImageNet.
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    ),
    "val": transforms.Compose(
        [
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    ),
}

data_dir = dataset_dir
image_datasets = {
    x if x == "train" else "val": datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x])
    for x in ["train", "val"]
}
dataset_sizes = {x: len(image_datasets[x]) for x in ["train", "val"]}
class_names = image_datasets["train"].classes
# Initialize dataloader
dataloaders = {
    x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True)
    for x in ["train", "val"]
}

# function to plot images
def imshow(inp, title=None):
    """Display image from tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    # Inverse of the initial normalization operation.
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders["train"]))

print(np.shape(inputs))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

print(np.shape(out))

imshow(out, title=[class_names[x] for x in classes])

# In order to get reproducible results, we set a manual seed for the
# random number generator and re-initialize the dataloaders.

torch.manual_seed(rng_seed)
dataloaders = {
    x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True)
    for x in ["train", "val"]
}
# Out:
# torch.Size([8, 3, 224, 224])
# torch.Size([3, 228, 1810])

# %% [markdown]
# ## Define quantum layer to replace the fc-layer of pre-trained resnet-18

# %% [markdown]
# ### Variational Quantum Circuit

# %% [markdown]
# #### Define base quantum layers
# Define quantum layers that will compose the quantum circuit
# - Hadamard (for making superposition)
# - Ry & Entanglement

# %%
# 1st - Prepare the Quantum Gates
def H_layer(nqubits):
    """Layer of single-qubit Hadamard gates.
    """
    for idx in range(nqubits):
        qml.Hadamard(wires=idx)
        
def RY_layer(w):
    """Layer of parametrized qubit rotations around the y axis.
    """
    for idx, element in enumerate(w):
        qml.RY(element, wires=idx)
        
def entangling_layer(nqubits):
    """Layer of CNOTs followed by another shifted layer of CNOT.
    """
    # In other words it should apply something like :
    # CNOT  CNOT  CNOT  CNOT...  CNOT
    #   CNOT  CNOT  CNOT...  CNOT
    for i in range(0, nqubits - 1, 2):  # Loop over even indices: i=0,2,...N-2
        qml.CNOT(wires=[i, i + 1])
    for i in range(1, nqubits - 1, 2):  # Loop over odd indices:  i=1,3,...N-3
        qml.CNOT(wires=[i, i + 1])

# %% [markdown]
# #### Define Quantum Circuit
# Define the quantum circuit through the PennyLane qnode decorator. The structure is that of a typical variational quantum circuit:
# - Embedding layer: All qubits are first initialized in a balanced superposition of up and down states, then they are rotated according to the input parameters (local embedding).
# - Variational layers: A sequence of trainable rotation layers and constant entangling layers is applied.
# - Measurement layer: For each qubit, the local expectation value of the
# Z operator is measured. This produces a classical output vector, suitable for additional post-processing.

# %%
@qml.qnode(dev, interface="torch")
def quantum_net(q_input_features, q_weights_flat):
    """
    The variational quantum circuit.
    """
    # Reshape weights
    q_weights = q_weights_flat.reshape(q_depth, n_qubits)

    # Start from state |+> , unbiased w.r.t. |0> and |1>
    H_layer(n_qubits)
    
    # Embed features in the quantum node
    RY_layer(q_input_features)
    
    # Sequence of trainable variational layers
    for k in range(q_depth):
        entangling_layer(n_qubits)
        RY_layer(q_weights[k])
        
    # Expectation values in the Z basis
    exp_vals = [qml.expval(qml.PauliZ(position)) for position in range(n_qubits)]
    return tuple(exp_vals)

# %% [markdown]
# #### Define a custom torch.nn.Module representing a dressed quantum circuit.
#
# This is a concatenation of:
# - A classical pre-processing layer (nn.Linear)
# - A classical activation function (torch.tanh)
# - A constant np.pi/2.0 scaling
# - The previously defined quantum circuit (quantum_net)
# - A classical post-processing layer (nn.Linear)
#
# The input of the module is a batch of vectors with 512 real parameters (features) and the output is a batch of vectors with two real outputs (associated with the two classes of images: face_mask and face_nomask).

# %%
# 2nd - Prepare the Replacement Quantum Layer
class DressedQuantumNet(nn.Module):
    """
    Torch module implementing the *dressed* quantum net.
    """

    def __init__(self):
        """
        Definition of the *dressed* layout.
        """

        super().__init__()
        self.pre_net = nn.Linear(512, n_qubits)
        self.q_params = nn.Parameter(q_delta * torch.randn(q_depth * n_qubits))
        self.post_net = nn.Linear(n_qubits, 2)

    def forward(self, input_features):
        """
        Defining how tensors are supposed to move through the *dressed* quantum
        net.
        """

        # obtain the input features for the quantum circuit
        # by reducing the feature dimension from 512 to 4
        pre_out = self.pre_net(input_features)
        q_in = torch.tanh(pre_out) * np.pi / 2.0

        # Apply the quantum circuit to each element of the batch and append to q_out
        q_out = torch.Tensor(0, n_qubits)
        q_out = q_out.to(device)
        for elem in q_in:
            q_out_elem = quantum_net(elem, self.q_params).float().unsqueeze(0)
            q_out = torch.cat((q_out, q_out_elem))

        # return the two-dimensional prediction from the postprocessing layer
        return self.post_net(q_out)

# %% [markdown]
# #### Build a full hybrid classical-quantum network
#
# Following the transfer learning approach:
#
# - load the classical pre-trained network ResNet18 from the torchvision.models zoo
# - freeze all the weights since they should not be trained
# - replace the last fully connected layer with our trainable dressed quantum circuit (DressedQuantumNet)

# %%
# 3rd - Replace last layer of resnet-18 with defined quantum layer
model_hybrid = torchvision.models.resnet18(pretrained=True)

for param in model_hybrid.parameters():
    param.requires_grad = False

# Notice that model_hybrid.fc is the last layer of ResNet18
model_hybrid.fc = DressedQuantumNet()

# Use CUDA or CPU according to the "device" object.
model_hybrid = model_hybrid.to(device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
criterion = nn.CrossEntropyLoss()
optimizer_hybrid = optim.Adam(model_hybrid.fc.parameters(), lr=step)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_hybrid, step_size=10, gamma=gamma_lr_scheduler)

# %% [markdown]
# # 2. Retrain

# %% [markdown]
# ## Define how to retrain the DressedQuantumNet (last layer)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs, temp_model_name):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_loss = 10000.0  # Large arbitrary number
    best_acc_train = 0.0
    best_loss_train = 10000.0  # Large arbitrary number
    
    for epoch in range(num_epochs):
        # Each epoch has a training and validation phase
        for phase in ["train", "val"]:
            if phase == "train":
                # Set model to training mode
                model.train()
            else:
                # Set model to evaluate mode
                model.eval()
            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            n_batches = dataset_sizes[phase] // batch_size
            it = 0
            for inputs, labels in dataloaders[phase]:
                since_batch = time.time()
                batch_size_ = len(inputs)
                inputs = inputs.to(device)
                labels = labels.to(device)
                optimizer.zero_grad()

                # Track/compute gradient and make an optimization step only when training
                with torch.set_grad_enabled(phase == "train"):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()

                # Print iteration results
                running_loss += loss.item() * batch_size_
                batch_corrects = torch.sum(preds == labels.data).item()
                running_corrects += batch_corrects
                message = "     > Phase: {} Epoch: {}/{} Iter: {}/{} Batch time: {:.4f}".format(
                                    phase,
                                    epoch + 1,
                                    num_epochs,
                                    it + 1,
                                    n_batches + 1,
                                    time.time() - since_batch,
                                 )
                # Print to screen with flush=True 
                print(message,
                        end="\r",
                        flush=True,
                )
                it += 1

            # Print epoch results
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]
            message = "     > Phase: {} Epoch: {}/{} Loss: {:.4f} Acc: {:.4f}".format(
                                "train" if phase == "train" else "val  ",
                                epoch + 1,
                                num_epochs,
                                epoch_loss,
                                epoch_acc,
                            )

            # Check if this is the best model wrt previous epochs
            if phase == "val" and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == "val" and epoch_loss < best_loss:
                best_loss = epoch_loss
            if phase == "train" and epoch_acc > best_acc_train:
                best_acc_train = epoch_acc
            if phase == "train" and epoch_loss < best_loss_train:
                best_loss_train = epoch_loss

            train_Acc = "{:.4f}".format(best_acc_train)
            train_Loss = "{:.4f}".format(best_loss_train)
            val_Acc = "{:.4f}".format(best_acc)
            val_Loss = "{:.4f}".format(best_loss)
            
            # Update learning rate
            if phase == "train":
                scheduler.step()
        
        # save the retrained model at this epoch completion
        # epoch is saved as epoch+1 (so to start at 1 instead of 0)
        # ---------------------------------------------------------
        model_at_epoch = temp_model_name + "-at-epoch-"+ str(epoch+1) \
            + "(" + str(num_epochs) + ")-" + now_str + model_fileext
        torch.save(model_hybrid.state_dict(), model_at_epoch)
        
        # save results of trained model at this epoch
        # ------------------------------------------- 
        # append list of "epoch, train accuracy, train loss, val accuracy, val loss" per epoch completion
        #   accumulate in train_val_results
        if epoch==0:
            # create first row
            train_val_results = np.array([[epoch+1, best_acc_train, best_loss_train, best_acc, best_loss]])
        else:
            train_result_at_epoch = np.array([[epoch+1, best_acc_train, best_loss_train, best_acc, best_loss]])
            # append new row
            train_val_results = np.append(train_val_results, train_result_at_epoch, axis=0) 
        
    # Write train_val_results to file
    np.save(train_val_filename, train_val_results)
    
    # Print final results
    model.load_state_dict(best_model_wts)
    time_elapsed = time.time() - since
    total_training_time = "{:.0f}m {:.0f}s".format(time_elapsed // 60, time_elapsed % 60)
    total_training_time = "{:.0f}m {:.0f}s".format(time_elapsed // 60, time_elapsed % 60)
    return model, total_training_time, train_Acc, train_Loss, val_Acc, val_Loss, train_val_results

# %% [markdown]
# ## Re-train the quantum layer

# %%
model_hybrid, total_training_time, train_Acc, train_Loss, val_Acc, val_Loss, train_val_results = train_model(
    model_hybrid, criterion, optimizer_hybrid, exp_lr_scheduler, num_epochs=num_epochs, temp_model_name = interim_model_name)

# %%
# SAVE final retrained Resnet-18 model
# ------------------------------------
torch.save(model_hybrid.state_dict(), hybrid_model_name)

# %%
# PRINT training summary
# ----------------------
from prettytable import PrettyTable
    
t_summary = PrettyTable()
t_summary.field_names = ["QC backend", "epoch", "batch size", \
    "train time", "train Acc", "train Loss", "val Acc", "val Loss"]
t_summary.add_row([backend_name, num_epochs, batch_size, \
    total_training_time, train_Acc, train_Loss, val_Acc, val_Loss])

# %%
for x in train_val_results:
    print(x)
# Out:
# [1.         0.74119886 0.52771229 0.85286783 0.42495313]
# [2.         0.87345385 0.36183454 0.8553616  0.38555199]
# [3.         0.89628925 0.3162204  0.88778055 0.30566416]
# [4.         0.89628925 0.31352784 0.89526185 0.29894033]
# [5.         0.89628925 0.30925191 0.90773067 0.26310772]
# [6.         0.89628925 0.26613467 0.92518703 0.24319845]
# [7.         0.92102759 0.23145222 0.9276808  0.21803786]
# [8.         0.93244529 0.21095349 0.9276808  0.21803786]

# %%
epoch = []
train_acc = []
train_loss = []
val_acc =[]
val_loss = []

for i in range(0, len(train_val_results)):
    epoch = np.append(epoch, train_val_results[i,0])
    train_acc = np.append(train_acc, train_val_results[i,1])
    train_loss = np.append(train_loss, train_val_results[i,2])    
    val_acc = np.append(val_acc, train_val_results[i,3])
    val_loss = np.append(val_loss, train_val_results[i,4])

# %%
# PLOT graph - training/validation accuracy, loss
# -----------------------------------------------
x1 = epoch
x2 = epoch
y1 = train_acc
y2 = val_acc

# plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('Training Summary: ' + backend_name)
plt.ylabel('train/val accuracy')

# plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('Epoch')
# plt.ylabel('train/val accuracy')

plt.legend(["train accuracy","val accuracy"])
plt.show()

# %%
# PLOT graph - training/validation accuracy, loss
# -----------------------------------------------
y1 = train_loss
y2 = val_loss

# plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('Training Summary: ' + backend_name)
plt.ylabel('train/val loss')

# plt.subplot(2, 1, 2)
plt.plot(x2, y2, '.-')
plt.xlabel('Epoch')
# plt.ylabel('train/val loss')

plt.legend(["train loss","val loss"])
plt.show()

# %%
# INSPECT the retrained Resnet-18 model neural network architecture
# -----------------------------------------------------------------
model_arch = model_hybrid.eval()

# %% [markdown]
# # 3. Test/Predict using the re-trained model

# %%
def visualize_model(model, num_images=4, fig_name="Predictions"):
    images_so_far = 0
    _fig = plt.figure(fig_name, figsize=(15,15))
    model.eval()
    with torch.no_grad(): # inferencing
        for _i, (inputs, labels) in enumerate(dataloaders["val"]):
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            # Expectation value is probabilistic expected value of the result (measurement) of an experiment
            # Pennylane implements the quantum measurement in such a way that:
            #  - if the first qubit is non zero, it puts negative to the measurement
            # expvals is expectation value of predicted class
            expvals, preds = torch.max(outputs, 1)
            # expvals_min is expectation value of another class as we only have 2 image classes/categories here
            expvals_min, preds_min = torch.min(outputs, 1)
            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images // 2, 2, images_so_far)
                ax.axis("off")
                title = "Detected as <" + class_names[preds[j]] + ">, Expectation Value: " + \
                    "{:.5f}".format(expvals[j]) + " (" + \
                    "{:.5f}".format(expvals_min[j]) + ")" 
                ax.set_title("[{}]".format(title))
                imshow(inputs.cpu().data[j])
                if images_so_far == num_images:
                    return

# %%
visualize_model(model_hybrid, num_images=4, fig_name="Predictions")
plt.show()

# %% [markdown]
# # Save and Load Hybrid Model

# %%
torch.save(model_hybrid, 'hybrid_model.h5')

# %%
test_model = torch.load('/content/hybrid_model.h5')
